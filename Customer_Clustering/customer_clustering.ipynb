# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "\\common")

from clustering import *

methods = {
    'imputer': None,
    'mapping': None,
    'dim_reduce': True,
    #'preprocess': MinMaxScaler((-1, 1))
}

mapping = {
    'Gender': {
        'Male': 0, 
        'Female': 1
    }
}
df = pd.read_csv('Mall_Customers.csv')
cluster = Clustering('Mall_Customers.csv', 
                         [f for f in df.columns if f != 'CustomerID'],
                         None,
                        #delimiter=','
                        )

cluster.set_mapping(mapping)
cluster.set_methods_process(methods)
cluster.run()
cluster.plot_clusters('Annual Income (k$)', 'Spending Score (1-100)')
# Out:
# position to choose:  2
# best n cluster:  5
# 0      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 123         124       0   39                  69                      91
# 125         126       1   31                  70                      77
# 127         128       0   40                  71                      95
# 129         130       0   38                  71                      75
# 131         132       0   39                  71                      75
# 133         134       1   31                  72                      71
# 135         136       1   29                  73                      88
# 137         138       0   32                  73                      73
# 139         140       1   35                  74                      72
# 141         142       0   32                  75                      93
# 143         144       1   32                  76                      87
# ...
